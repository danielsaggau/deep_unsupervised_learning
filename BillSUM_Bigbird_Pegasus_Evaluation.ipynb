# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsaggau/deep_unsupervised_learning/blob/main/BillSUM_Bigbird_Pegasus_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Evaluate 🤗's BigBirdPegasus on Pubmed**

# %% [markdown]
# In this notebook, we evaluate BigBird on the long-range summarization task of **[pubmed](https://huggingface.co/datasets/scientific_papers)**. BigBird was introduced in [Big Bird: Transformers for Longer Sequences](https://arxiv.org/abs/2007.14062) by *Manzil Zaheer et al.* It has achieved outstanding performance on long document summarization using an efficient block sparse attention mechanism. Please refer to this [blog post](https://huggingface.co/blog/big-bird) for an in-detail explanation of BigBird's block sparse attention.

# %% [markdown]
# Let's see what GPU we got. We need at least ~12 GB GPU memory to be able to run this notebook.

# %%
# !nvidia-smi

# %% [markdown]
# Let's first install `transformers`, `datasets`, `rouge_score` and `sentencepiece`.

# %%
# %%capture
# !pip3 install datasets
# !pip3 install rouge_score
# !pip3 install git+https://github.com/huggingface/transformers
# !pip3 install sentencepiece

# %% [markdown]
# As mentioned above, we will evaluate **BigBirdPegasus** on the **_pubmed_** dataset using the **Rouge-2** metric. For this, let's
# import the two loading functions `load_dataset` and `load_metric`. Futher, we import the `BigBirdPegasusForConditionalGeneration` and `AutoTokenizer` tokenizer.

# %%
from datasets import load_dataset, load_metric
import torch
from transformers import BigBirdPegasusForConditionalGeneration, AutoTokenizer

# %% [markdown]
# Let's define some variables which will be useful later on.

# %%
DATASET_NAME = "billsum"
DEVICE = "cuda"
CACHE_DIR = DATASET_NAME
MODEL_ID = f"google/bigbird-pegasus-large-bigpatent"

# %% [markdown]
# To begin with, let's take a look at the PubMed dataset ([click to see on 🤗Datasets Hub](https://huggingface.co/datasets/scientific_papers)).
# PubMed consists of scientific papers in the field of medicine. The dataset splits each paper into the *article*, and the *abstract* whereas the article consists of the whole paper minus the abstract. Thus, the input to be summarized is defined by the article and the gold label by the abstract.
#
# The following table summarizes the size of the *train*, *validation*, and *test* split of the dataset.
#
# |               |Training | Validation | Test |
# |---------------|---------|------------|------|
# | Total samples | 119924  | 6633       | 6658 |

# %% [markdown]
# In this notebook, we are only interested in evaluating *BigBird*. To do so, let's download the *test* split of the `pubmed` dataset. This can take a couple of minutes **☕** .

# %%
test_dataset = load_dataset("billsum", DATASET_NAME, split="test", cache_dir=CACHE_DIR)
test_dataset
# Out:
# Downloading:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/832 [00:00<?, ?B/s]
# Using custom data configuration billsum
# Downloading and preparing dataset billsum/billsum to billsum/billsum/billsum/3.0.0/d1e95173aed3acb71327864be74ead49b578522e4c7206048b2f2e5351b57959...
# Downloading: 0.00B [00:00, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset billsum downloaded and prepared to billsum/billsum/billsum/3.0.0/d1e95173aed3acb71327864be74ead49b578522e4c7206048b2f2e5351b57959. Subsequent calls will reuse this data.
# Dataset({
#     features: ['text', 'summary', 'title'],
#     num_rows: 3269
# })

# %% [markdown]
# The official checkpoint `google/bigbird-pegasus-large-pubmed` ([click to see on 🤗Model Hub](https://huggingface.co/google/bigbird-pegasus-large-pubmed)) has already been fine-tuned on pubmed, so we can simply load the weights are run the model in inference mode.

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
model = BigBirdPegasusForConditionalGeneration.from_pretrained(MODEL_ID).to(DEVICE)
rouge = load_metric("rouge")
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.83M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.35M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/775 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %% [markdown]
# `BigBirdPegasus` makes use of *block sparse attention*. Let's verify the `config`'s attention type and the `block_size`.

# %%
model.config.attention_type, model.config.block_size
# Out:
# ('block_sparse', 64)

# %% [markdown]
# Next, we will take a look at the length distribution of the dataset. The following table shows the *median* and the 90% quantile of the article, and abstract (summary).
#
# |                 | Median | 90%-ile |
# |-----------------|--------|---------|
# | Articles Length | 2715   | 6101    |
# | Summary Length  | 212    | 318     |
#
# `BigBirdPegasus` can handle sequence up to a length of **4096** which is significantly higher than the median input length of **2715**. However, many input samples are longer than **4096**, which consequently need to be truncated.
# The summaries have a median length of **212** with 90% being shorter than **318**. Given this data, 256 seems to be a reasonable choice as the model's maximum generation length.

# %% [markdown]
# Now we can write the evaluation function for BigBirdPegasus.
# First, we tokenize each *article* up to a maximum length of 4096 tokens.
# We will make use of beam search (with `num_beams=5` & `length_penalty=0.8`) to generate the predicted *abstract* of the *article*. Finally, the predicted *abstract* tokens are decoded and the resulting predicted *abstract* string is saved in the batch.

# %%
def generate_answer(batch):
  inputs_dict = tokenizer(batch["text"], padding="max_length", max_length=4096, return_tensors="pt", truncation=True)
  inputs_dict = {k: inputs_dict[k].to(DEVICE) for k in inputs_dict}
  predicted_abstract_ids = model.generate(**inputs_dict, max_length=256, num_beams=5, length_penalty=0.8)
  batch["predicted_abstract"] = tokenizer.decode(predicted_abstract_ids[0], skip_special_tokens=True)
  print(batch["predicted_abstract"])
  return batch

# %% [markdown]
# Let's take 2 samples and verify the predictions to be sure everything works as expected 🙂.

# %%
dataset_small = test_dataset.select(range(2))
result_small = dataset_small.map(generate_answer)

rouge.compute(predictions=result_small["predicted_abstract"], references=result_small["summary"])
# Out:
#   0%|          | 0/2 [00:00<?, ?ex/s]
# in this brief reply to a recent letter to [ s.- a. ], we point out that there is an error in [ s.- a. ], and in [ s.- a. ], in [ s.- a. ], and in [ s.- a. ], in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s
# in this brief report, we attempt to answer some of the questions raised in the resolution of the following open question : 1. the answer to the question : 1. whether or not the 4th and 5th centuries are incompatible? 2. the answer to the question : 3. the answer to the question : 4. the answer to the question : 5. the answer to the question : 6. the answer to the question : 7. the answer to the question : 8. the answer to the question : 9. the answer to the question : 10. the answer to the question : 11. the answer to the question : 12. the answer to the question : 13. the answer to the question : 14. the answer to the question : 15. the answer to the question : 16. the answer to the question : 17. the answer to the question : 18. the answer to the question : 19. the answer to the question : 20. the answer to the question : 21. the answer to the question : 22.
# {'rouge1': AggregateScore(low=Score(precision=0.050314465408805034, recall=0.07028753993610223, fmeasure=0.0784313725490196), mid=Score(precision=0.16439773903351643, recall=0.12403265885694001, fmeasure=0.09533813525410165), high=Score(precision=0.27848101265822783, recall=0.17777777777777778, fmeasure=0.11224489795918367)),
#  'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.006329113924050633, recall=0.022727272727272728, fmeasure=0.009900990099009901), high=Score(precision=0.012658227848101266, recall=0.045454545454545456, fmeasure=0.019801980198019802)),
#  'rougeL': AggregateScore(low=Score(precision=0.0440251572327044, recall=0.05750798722044728, fmeasure=0.06862745098039215), mid=Score(precision=0.13593662924926359, recall=0.10653177138800142, fmeasure=0.08023209283713485), high=Score(precision=0.22784810126582278, recall=0.15555555555555556, fmeasure=0.09183673469387756)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.050314465408805034, recall=0.05750798722044728, fmeasure=0.0784313725490196), mid=Score(precision=0.1390812833373139, recall=0.11764288249911253, fmeasure=0.08513405362144857), high=Score(precision=0.22784810126582278, recall=0.17777777777777778, fmeasure=0.09183673469387756))}

# %% [markdown]
# Because of the very large input size of ~ 4K tokens in this notebook, it would take over (time) to evaluate the whole filtered test dataset. For the sake of this notebook, we'll only evaluate the first 600 examples. Therefore, we cut the 6000+ samples to just 600 samples using 🤗Datasets' convenient `.select()` function.

# %%
test_dataset = test_dataset.select(range(100))

# %% [markdown]
# Alright, now let's map each sample to the predicted *abstract*. This will take *ca.* 2 hours if you have been given a fast GPU.

# %%
result = test_dataset.map(generate_answer)
# Out:
#   0%|          | 0/100 [00:00<?, ?ex/s]
# in this brief reply to a recent letter to [ s.- a. ], we point out that there is an error in [ s.- a. ], and in [ s.- a. ], in [ s.- a. ], and in [ s.- a. ], in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s.- a. ], respectively, in [ s.- a ], and in [ s
# in this brief report, we attempt to answer some of the questions raised in the resolution of the following open question : 1. the answer to the question : 1. whether or not the 4th and 5th centuries are incompatible? 2. the answer to the question : 3. the answer to the question : 4. the answer to the question : 5. the answer to the question : 6. the answer to the question : 7. the answer to the question : 8. the answer to the question : 9. the answer to the question : 10. the answer to the question : 11. the answer to the question : 12. the answer to the question : 13. the answer to the question : 14. the answer to the question : 15. the answer to the question : 16. the answer to the question : 17. the answer to the question : 18. the answer to the question : 19. the answer to the question : 20. the answer to the question : 21. the answer to the question : 22.
# we find the following. 1. <n> we dedicate this letter to the memory of albert einstein.<n> 2. <n> we dedicate this letter to the memory of albert einstein.<n> 3. <n> we dedicate this letter to the memory of albert einstein.<n> 4. <n> we dedicate this letter to the memory of albert einstein.<n> 5. <n> we dedicate this letter to the memory of albert einstein.<n>
# in this paper we address the question as to the nature of the partnership formed by the stichting landessternwarte wissenschaft mbh ( stichting gmbh ) and the stichting gmbh.<n> we show that the stichting gmbh and the stichting gmbh, as well as the stichting gmbh are not limited to each other.<n> we show that the relationship between the stichting gmbh and the stichting gmbh, as well as the relationship between the stichting gmbh and the stichting gmbh, as well as the relationship between the stichting gmbh and the stichting gmbh, as well as the relationship between the stichting gmbh and the stichting gmbh, as well as the relationship between the stichting gmbh and the stichting gmbh, as well as the relationship between the stichting gmbh and the stichting gmbh, as well as the relationship between the stichting gmbh and the stichting gmbh, as well as the
# we address the issue of self- regulation of an investment fund. <n> [ [ section ] ] the purpose of this article is to address the issue of self - regulation of an investment fund. <n> [ [ section ] ] the purpose of this article is to address the issue of self- regulation of an investment fund. <n> [ [ section ] ] the purpose of this article is to address the issue of self- regulation of an investment fund. <n> [ [ section ] ] the purpose of this article is to address the issue of self- regulation of an investment fund. <n> [ [ section ] ] the definition of an investment fund. <n> [ [ section ] ] the definition of an investment fund. <n> [ [ section ] ] the definition of an investment fund. <n> [ [ section ] ] the definition of an investment fund. <n> [ [ section ] ] the definition of an investment fund. <n> [ [ section ] ] the definition of an investment fund. <n> [ [ section ] ] the definition of an investment fund. <n> [ [ section
# we show that the law of limited access to controlled substances in the united states can be violated by a practitioner who prescribes a controlled substance in a way that is inconsistent with the practitioner s training and expertise.<n> specifically, we show that a practitioner who prescribes a controlled substance in a way that is inconsistent with the practitioner s training and expertise may be imprisoned for not more than ten years, and a practitioner who prescribes a controlled substance in a way that is inconsistent with the practitioner s training and expertise may be imprisoned for not more than ten years, may be placed on leave of absence from the prescriber for not more than ten years, and a practitioner who prescribes a controlled substance in a way that is inconsistent with the practitioner s training and expertise may be placed on leave of absence from the prescriber for not more than ten years. <n> [ [ section ] ] limited access to controlled substances in the united states can be violated by a practitioner who prescribes a controlled substance in a way that is inconsistent with the practitioner s training and expertise.<n> specifically, we show that a practitioner who prescribes a controlled substance in a way that is inconsistent with the practitioner s training and expertise may be
# we address the issue of whether or not to set limits on the amount of money that can be raised from a single user fee for the right to use any public transportation system in the united states of america.<n> we do not address the question of whether or not to set limits on the amount of money that can be raised from a single user fee for the right to use any public transportation system in the united states of america.<n> we address the question of whether or not to set limits on the amount of money that can be raised from a single user fee for the right to use any public transportation system in the united states of america.<n> we do not address the question of whether or not to set limits on the amount of money that can be raised from a single user fee for the right to use any public transportation system in the united states of america.<n> we address the issue of whether or not to set limits on the amount of money that can be raised from a single user fee for the right to use any public transportation system in the united states of america.
# in this brief report, we attempt to answer some of the questions raised in @xcite and @xcite, as well as in @xcite and @xcite.
# in this chapter, we provide definitions of the following entities : ( 1 ) the university, ( 2 ) the school of mathematics, ( 3 ) the college of education, ( 4 ) the college of science, ( 5 ) the library, ( 6 ) the library of engineering, ( 7 ) the physics department, ( 8 ) the physics department, ( 9 ) the physics department, ( 10 ) the library of engineering, ( 11 ) the physics department, ( 12 ) the physics department, ( 13 ) the library of engineering, ( 14 ) the physics department, ( 15 ) the physics department, ( 16 ) the library of engineering, ( 17 ) the physics department, ( 18 ) the physics department, ( 19 ) the library of engineering, ( 20 ) the physics department, ( 21 ) the physics department, ( 22 ) the library of engineering, ( 23 ) the physics department, ( 26 ) the physics department, ( 27 ) the library of engineering, ( 28 ) the physics department
# this paper is concerned with the question of whether or not a cessation of smoking in a public place is inconsistent with the fundamental right to freedom of expression.<n> we show that under certain circumstances, a cessation of smoking in a public place is inconsistent with the fundamental right to freedom of expression. in particular, we show that a cessation of smoking in a public place is inconsistent with the fundamental right to freedom of expression. <n> 2 [ [ section ] ] the aim of this paper is to show that under certain circumstances, a cessation of smoking in a public place is inconsistent with the fundamental right to freedom of expression. in particular, we show that under certain circumstances, a cessation of smoking in a public place is inconsistent with the fundamental right to freedom of expression. <n> [ [ section ] ] the aim of this paper is to show that under certain circumstances, a cessation of smoking in a public place is inconsistent with the fundamental right to freedom of expression. <n> [ [ section ] ] the aim of this paper is to show that under certain circumstances, a cessation of smoking in a public place is inconsistent with the fundamental right to freedom of expression. <n> [ [ section
# we address the question of whether or not the law of conservation of energy places constraints on the amount of energy that can be extracted from the sea for a given purpose.<n> we do so by establishing a relationship between the amount of energy that can be extracted from the sea and the amount of energy that can be extracted from the sea for a given purpose. <n> [ theoree]proposition [ theoree]corollary [ theoree]lemma [ theoree]remark [ theoree]definition [ theoree]example
# this paper presents a case study of a social service organization ( sso ) that provides supports to individuals and their families.<n> the case study concerns the case study of a case worker who works for the sso and is on leave from her job as well as the case study of a case worker who works for the sso and is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a case worker who is on leave from her job as well as the case study of a
# a higher education accrediting agency has been sanctioned by the regional accrediting agency for education and/or science ( ral ) of the u.s. under the _ national standards for higher education _,<n> _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# hydrogen is the third most abundant element in the universe after helium and carbon monoxide. in spite of its importance,<n> hydrogen is not yet fully understood. in this report,<n> we attempt to answer some of the basic questions as to : 1. <n> what is hydrogen? 2. <n> how is hydrogen produced? 3. <n> how is hydrogen transported?<n> 4. <n> how is hydrogen transported?<n> 5. <n> how is hydrogen distributed?<n> 6. <n> how is hydrogen transported?<n> 7. <n> how is hydrogen distributed?<n> 8. <n> the purpose of this report is to present a brief overview of the hydrogen energy budget, hydrogen transportation, hydrogen storage, hydrogen production and hydrogen consumption.
# we report an abundance of methylcury, a heavy metal, in the ocean and in the atmosphere.<n> we find that the level of methylcury in the ocean is @xmath0 g @xmath1 s@xmath2 and the level of methylcury in the atmosphere is @xmath3 g @xmath1 s@xmath2.<n> we find that the level of methylcury in the ocean is @xmath4 g @xmath1 s@xmath2 and the level of methylcury in the atmosphere is @xmath5 g @xmath1 s@xmath2.<n> we find that the level of methylcury in the ocean is @xmath6 g @xmath1 s@xmath2 and the level of methylcury in the atmosphere is @xmath7 g @xmath1 s@xmath2.<n> we find that the level of methylcury in the ocean is @xmath8 g @xmath1 s@xmath2 and the level of methylcury in the atmosphere is @xmath9 g @xmath1 s@xmath2.<n> we find
# we consider the question of whether there is a lower bound on the amount of money that can be spent to remove a contaminant from a water reservoir.<n> specifically, we address the question of whether there is a lower bound on the amount of money that can be spent to remove a contaminant from a water reservoir. <n> [ [ section ] ] the purpose of this paper is to consider the question of whether there is a lower bound on the amount of money that can be spent to remove a contaminant from a water reservoir.<n> specifically, we consider the question of whether there is a lower bound on the amount of money that can be removed to remove a contaminant from a water reservoir. <n> [ [ section ] ] the purpose of this paper is to consider the question of whether there is a lower bound on the amount of money that can be removed to remove a contaminant from a water reservoir. <n> [ [ section ] ] the purpose of this paper is to consider the question of whether there is a lower bound on the amount of money that can be removed to remove a contaminant from a water reservoir. <n> [ [ section ] ] the purpose of this paper is to consider the question of whether there
# we address the issue of coding for subjective subjective subjective assessment of subjective subjective assessment of subjective subjective assessment of subjective assessment by a physician.<n> we show that the subjective assessment of subjective assessment of subjective assessment of subjective assessment by a physician may be expressed in the following way : 1. <n> the subjective assessment of subjective assessment of subjective assessment of subjective assessment by a physician may be expressed in the following way : 1. <n> the subjective assessment of subjective assessment of subjective assessment of subjective assessment by a physician may be expressed in the following way : 1. <n> the subjective assessment of subjective assessment of subjective assessment by a physician may be expressed in the following way : 1. <n> the subjective assessment of subjective assessment of subjective assessment of subjective assessment by a physician may be expressed in the following way : 1. <n> the subjective assessment of subjective assessment of subjective assessment of subjective assessment by a physician may be expressed in the following way : 1. <n> the subjective assessment of subjective assessment of subjective assessment of subjective assessment by a physician may be expressed in the following way : 1. <n> the subjective assessment of subjective assessment of subjective assessment by a physician may be expressed in the following way : 1.
# this paper presents a case study of an academic reinterpretation of an exam.<n> the case study concerns the evaluation of an academic reinterpretation of an exam.<n> the case study concerns the evaluation of an academic reinterpretation of an exam.<n> the case study concerns the evaluation of an academic reinterpretation of an exam. <n> _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# we address the question of whether or not the state of virginity is a sufficient condition for a person to be held responsible for a violent crime.<n> specifically, we address the following question : is the state of virginity a sufficient condition for a person to be held responsible for a violent crime? <n> the state of virginity is a sufficient condition for a person to be held responsible for a violent crime if the following two conditions are satisfied : 1. <n> ) the state of virginity is a sufficient condition for a person to be held responsible for a violent crime if the following two conditions are satisfied : 1. <n> ) the state of virginity is a sufficient condition for a person to be held responsible for a violent crime if the following two conditions are satisfied : 1. <n> ) the state of virginity is a sufficient condition for a person to be held responsible for a violent crime if the following two conditions are satisfied : 1. <n> ) the state of virginity is a sufficient condition for a person to be held responsible for a violent crime if the following two conditions are satisfied : 1. <n> ) the state of virginity is a sufficient condition for
# in this paper we address the question of whether there is a lower bound on the value of a real property in order to ensure that it can be used for historical purposes. <n>.2 in this paper we address the question of whether there is a lower bound on the value of a real property in order to ensure that it can be used for historical purposes. <n>.2 in this paper we address the question of whether there is a lower bound on the value of a real property in order to ensure that it can be used for historical purposes. <n>.2 in this paper we address the question of whether there is a lower bound on the value of a real property in order to ensure that it can be used for historical purposes. <n>.2 in this paper we address the question of whether there is a lower bound on the value of a real property in order to ensure that it can be used for historical purposes. <n>.2 in this paper we address the question of whether there is a lower bound on the value of a real property in order to ensure that it can be used for historical purposes. <n>.2 in this paper we address the question of whether there is a lower bound on
# we show that the definition of a contribution to an international organization is not sufficient to determine whether an individual has or has not contributed to an international organization. <n> [ theo]*theorem * [ theo]proposition [ theo]lemma [ theo]corollary [ theo]definition [ theo]remark [ theo]example [ theo]proposition [ theo]conjecture
# we report the results of an analysis of the capabilities and requirements of the nuclear forces of the korean air force.<n> we find that the korean air force s capabilities and requirements are in conflict with those of the air force of the russian air force.<n> we also find that the requirements of the air force of the russian air force are in conflict with those of the air force of the united states of america, the united states navy, the air force of the russian academy of sciences, and the air force of the russian academy of sciences.<n> we find that the requirements of the air force of the russian air force are in conflict with those of the air force of the united states of america, the united states navy, the air force of the russian academy of sciences, and the air force of the russian academy of sciences.<n> we find that the requirements of the air force of the russian air force are in conflict with those of the air force of the united states of america, the united states navy, the air force of the russian academy of sciences, and the air force of the russian academy of sciences.<n> we find that the requirements of the air force of the russian air force are in conflict with
# we consider the question of whether or not a candidate for president of the united states of america is allowed to accept political contributions from outside the scope of his or her campaign committee. <n> [ section ] [ thm]proposition [ thm]lemma [ thm]corollary [ thm]definition [ thm]example [ thm]remark
# in this report, we address the question of whether or not a clinical diagnostic laboratory should be allowed to participate in a survey to obtain information on the appropriateness of that laboratory for that purpose. <n>./style / arxiv - vmsta.cfg clinical diagnostic laboratories, especially transcription laboratories, offer a wide range of services to the public.<n> the purpose of a clinical diagnostic laboratory is to provide, for the benefit of the public, accurate and reliable information on the classification and appropriateness of that laboratory for that purpose. in this report, we address the question of whether or not a clinical diagnostic laboratory should be allowed to participate in a survey to obtain information on the appropriateness of that laboratory for that purpose. <n>./style / arxiv - vmsta.cfg clinical diagnostic laboratories offer a wide range of services to the public.<n> the purpose of a clinical diagnostic laboratory is to provide, for the benefit of the public, accurate and reliable information on the classification and appropriateness of that laboratory for that purpose. in this report, we address the question of whether or not a clinical diagnostic laboratory should be allowed to participate in a survey to obtain information on the appropriateness of that laboratory
# this is an extension of a result of a v.i.d.<n> vassiliev case ( v.i.d. vassiliev case ( v.i.d. vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v.i.d.<n> vassiliev case ( v
# we address the following questions. 1.<n> let us state our case : let us state our case : let us state our case : let us state our case : [ 1 ] let us state our case : [ 2 ] let us state our case : [ 3 ] we state our case : [ 4 ] we state our case : [ 5 ] we state our case : [ 6 ] we state our case : [ 7 ] we state our case : [ 8 ] we state our case : [ 9 ] we state our case : [ 10 ] we state our case : [ 11 ] we state our case : [ 12 ] we state our case : [ 13 ] we state our case : [ 14 ] we state our case : [ 15 ] we state our case : [ 16 ] we state our case : [ 17 ] we state our case : [ 18 ] we state our case : [ 19 ] we state our case : [ 20 ] we state our case : [ 21 ] we state our case : [ 22 ]
# we report the results of an investigation into the widespread practice of using interpreters for non - military purposes.<n> specifically, we show that the widespread practice of using interpreters for non - military purposes is incompatible with the requirements of the services provided by the us mission and the laws of the united states of america.<n> we find that the practice of using interpreters for non - military purposes is inconsistent with the requirements of the services provided by the us mission and the laws of the united states of america.<n> we also find that the widespread practice of using interpreters for non - military purposes is inconsistent with the requirements of the services provided by the us mission and the laws of the united states of america.<n> we conclude that the practice of using interpreters for non - military purposes is inconsistent with the requirements of the services provided by the us mission and the laws of the united states of america. <n> [ cols= "  ", ] we report the results of an investigation into the widespread practice of using interpreters for non - military purposes.<n> specifically, we show that the widespread practice of using interpreters for non - military purposes is incompatible with the requirements of the services provided by the us mission and the laws of the united states of america
# this report describes the capabilities of the joint operations center ( roc ).<n> roc is the roc of the united states of america.<n> the report describes the capabilities of the joint operations center ( roc ).<n> roc is the roc of the united states of america.<n> the report describes the capabilities of the joint operations center ( roc ).<n> roc is the roc of the united states of america.<n> the report describes the capabilities of the joint operations center ( roc ).<n> roc is the roc of the united states of america.<n> the report describes the capabilities of the joint operations center ( roc ).<n> roc is the roc of the united states of america.<n> the report describes the capabilities of the joint operations center ( roc ).<n> roc is the roc of the united states of america.<n> the report describes the capabilities of the joint operations center ( roc ).<n> roc is the roc of the united states of america.<n> the report describes the capabilities of the joint operations center ( roc ).<n> roc is the roc
# we report the results of a study of the dependence of the national budget of an oil - rich sultanate on its oil consumption.<n> we find that the sultanate s oil consumption is determined by two factors.<n> the first is the dependence of the national budget on the oil consumption of the sultan.<n> the second is the dependence of the national budget on the oil consumption of the sultan.<n> we find that the dependence of the national budget on the oil consumption of the sultan is determined by two factors.<n> the first is the dependence of the national budget on the oil consumption of the sultan.<n> the second is the dependence of the national budget on the oil consumption of the sultan. <n> we report the results of a study of the dependence of the national budget of an oil - rich sultanate on its oil consumption.<n> we find that the dependence of the national budget on the oil consumption of the sultan is determined by two factors.<n> the first is the dependence of the national budget on the oil consumption of the sultan.<n> the second is the dependence of the national budget on the oil consumption of the sultan.<n> we find that the dependence of the
# an alien who is a member of a country which is not a separable union of more than two countries is an alien who is not a member of a union of more than two countries.<n> an alien who is not a member of a union of more than two countries is an alien who is not a member of a union of more than two countries.<n> an alien who is not a member of a union of more than two countries is an alien who is not a member of a union of more than two countries.<n> an alien who is not a member of a union of more than two countries is an alien who is not a member of a union of more than two countries.<n> an alien who is not a member of a union of more than two countries is an alien who is not a member of a union of more than two countries.<n> an alien who is not a member of a union of more than two countries is an alien who is not a member of a union of more than two countries.<n> an alien who is not a member of a union of more than two countries is an alien who is not a member of a union of more than two countries.<n> an alien who is not a member of a union
# the purpose of this chapter is to provide a definition of the training that an educational institution provides for its graduates.<n> we also provide a definition of the training that an educational institution provides for its graduates. <n> [ [ section ] ] the purpose of this chapter is to provide a definition of the training that an educational institution provides for its graduates. <n> [ [ section ] ] the definition of the training that an educational institution provides for its graduates. <n> [ [ section ] ] the definition of the training that an educational institution provides for its graduates. <n> [ [ section ] ] the definition of the training that an educational institution provides for its graduates. <n> [ [ section ] ] the definition of the training that an educational institution provides for its graduates. <n> [ [ section ] ] the definition of the training that an educational institution provides for its graduates. <n> [ [ section ] ] the definition of the training that an educational institution provides for its graduates. <n> [ [ section ] ] the definition of the training that an educational institution provides for its graduates. <n> [ [ section ] ] the definition of the
# we show that ( 1 ) : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# this is an elaboration of the proposal made by the author in her unpublished book :  _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# this paper reports the results of an evaluation of the impacts of climate change on water supply, including impacts on water quality, on the cost of water, on the impact of climate change on water supply, on the impact of water infrastructure on water supply, on the impact of water resources on the economy and on the water industry. <n> [ [ keywords ] ] keywords : + + + + + + + + climate change ; water supply ; climate change ; water resources ; infrastructure change ; water quality ; water infrastructure ; cost of water ; reuse. <n> [ [ mathematics - subject - classification-2010 ] ] mathematics subject classification ( 2010 ) : + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
# in this chapter we present the definition of a dividend.<n> the definition of a dividend is defined as : a dividend of a corporation is defined as : a dividend of a subgroup of the corporation is defined as : b a subgroup of the corporation is defined as : b a subgroup of the corporation is defined as : i a subgroup of the corporation is defined as : ii a subgroup of the corporation is defined as : iii a subgroup of the corporation is defined as :  iv a subgroup of the corporation is defined as : v a subgroup of the corporation is defined as : vi a subgroup of the corporation is defined as : v a subgroup of the corporation is defined as :  vi a subgroup of the corporation is defined as : vii a subgroup of the corporation is defined as : vi a subgroup of the corporation is defined as : v a subgroup of the corporation is defined as :  vi a subgroup of the corporation is defined as : v a subgroup of the corporation is defined as :  vi a subgroup of the corporation is defined
# women make up 46 percent of the workforce and make up 46 percent of fulltime managers in 10 of the largest companies in the country. yet, women make up only 1 percent of all scientists, editors and directors. in this work,<n> we report on the gender pay gap, in the year 2004, between women and men.<n> we find that the gender pay gap widens at the rate of 1 percent per year.<n> furthermore, we find that the gap widens at the rate of 1 percent per year.<n> we find that the gap widens at the rate of 1 percent per year. <n> [ [ section ] ] in this work, we report on the gender pay gap, in the year 2004, between women and men.<n> we find that the gap widens at the rate of 1 percent per year.<n> furthermore, we find that the gap widens at the rate of 1 percent per year. [ [ section ] ] in this work, we report on the gender pay gap, in the year 2004, between women and men.<n> we find that the gap widens at the rate of 1 percent per
# in this brief note, we point out that there is a conflict of interest when it comes to the definition of the cost of ownership in a real estate development.<n> the definition of the cost of ownership in a real estate development is as follows.<n> * 1. * the cost of ownership in a real estate development is defined as the difference between the value of the property and its market value.<n> * 2. * * the cost of ownership in a real estate development is defined as the difference between the value of the property and its market value.<n> * 3. * * the cost of ownership in a real estate development is defined as the difference between the value of the property and its market value. <n> the definition of the cost of ownership in a real estate development is as follows.<n> * 1. * * the cost of ownership in a real estate development is defined as the difference between the value of the property and its market value.<n> * 2. * * the cost of ownership in a real estate development is defined as the difference between the value of the property and its market value. <n> the definition of the cost of ownership in a real estate development is as follows.<n>
# this chapter is concerned with the employment of parttime employees of a governmental or non - governmental agency.<n> the employment of parttime employees of a governmental or non - governmental agency is made possible by the provisions of this chapter.<n> the employment of parttime employees of a governmental or non - governmental agency is made possible by the provisions of this chapter.<n> this chapter is concerned with the employment of parttime employees of a governmental or non - governmental agency.<n> the definition of a parttime employee of a governmental or non - governmental agency is the following : 1.<n> the definition of a parttime employee of a governmental or non - governmental agency is the following : 2.<n> the definition of a parttime employee of a governmental or non - governmental agency is the following : 3.<n> the definition of a parttime employee of a governmental or non - governmental agency is the following : 4.<n> the definition of a parttime employee of a governmental or non - governmental agency is the following : 5.<n> the definition of a parttime employee of a governmental or non - governmental agency is the following : 6. the definition of a parttime employee of a governmental or non - governmental agency is
# the purpose of this resolution is to establish an assessment on the volume of propane in the state of michigan.<n> the purpose of this resolution is to establish an assessment on the volume of propane in the state of michigan.<n> the purpose of this resolution is to establish an assessment on the volume of propane in the state of michigan.<n> the purpose of this resolution is to establish an assessment on the volume of propane in the state of michigan.<n> the purpose of this resolution is to establish an assessment on the volume of propane in the state of michigan.<n> the purpose of this resolution is to establish an assessment on the volume of propane in the state of michigan. <n> [ [ section ] ] the purpose of this resolution is to establish an assessment on the volume of propane in the state of michigan. <n> [ [ section ] ] the purpose of this resolution is to establish an assessment on the volume of propane in the state of michigan. <n> [ [ section ] ] the purpose of this resolution is to establish an assessment on the volume of propane in the state of michigan. <n> [ [ section ] ] the purpose of this resolution is to
# this paper deals with the question of whether or not the total consumption of water in a well is proportional to the water content of the well.<n> the water content of a well is defined as the ratio of the total consumption of water to the water content of the well.<n> the water content of a well is defined as the ratio of the total consumption of water to the water content of the well. <n> this paper deals with the question of whether or not the total consumption of water in a well is proportional to the water content of the well.<n> the water content of a well is defined as the ratio of the total consumption of water to the water content of the well.<n> this paper deals with the question of whether or not the total consumption of water in a well is proportional to the water content of the well. <n> the water content of a well is defined as the ratio of the total consumption of water to the water content of the well.<n> this paper deals with the question of whether or not the total consumption of water in a well is proportional to the water content of the well. <n> the water content of a well is defined as the ratio of the total consumption of water to the water content of the well
# we report the results of a search for potential candidates to be the next director of the national center for theoretical sciences ( ncw - tbilisi ).<n> we report the results of a search for potential candidates to be the next director of the national center for theoretical sciences ( ncw - tbilisi ).<n> we report the results of a search for potential candidates to be the next director of the national center for theoretical sciences ( ncw - tbilisi ).<n> we report the results of a search for potential candidates to be the next director of the national center for theoretical sciences ( ncw - tbilisi ). <n> _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# we report the results of an investigation into the nature of the irregularities observed in the results of the 2015 general election of the united states congress.<n> the results of the investigation show that the irregularities in the results of the election are of two kinds.<n> first, there are irregularities in the results of the votes of the members of the committee.<n> second, there are irregularities in the results of the votes of the individual members of the committee.<n> we report the results of an investigation into the nature of the irregularities observed in the results of the 2015 general election of the united states congress.<n> the results of the investigation show that the irregularities are of two kinds.<n> first, there are irregularities in the results of the votes of the members of the committee.<n> second, there are irregularities in the results of the individual members of the committee.<n> we report the results of an investigation into the nature of the irregularities observed in the results of the 2015 general election of the united states congress.<n> the results of the investigation show that the irregularities are of two kinds.<n> first, there are irregularities in the results of the votes of the members of the committee.<n> second, there are irregularities in
# we address the question of whether or not there is a lower bound on the price of a generic drug in the united states of america. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 1. <n> [ [ section ] ] 2. <n> [ [ section ] ] 3. <n> [ [ section ] ] 4. <n> [ [ section ] ] 5. <n> [ [ section ] ] 6. <n> [ [ section ] ] 7
# we address the question of whether a consumer has the right to know the costs of using a credit card.<n> specifically, we address the following question : does a consumer have the right to know the costs of using a credit card? <n> * 1. * a consumer has the right to know the costs of using a credit card.<n> * 2. * a consumer has the right to know the following : * does a consumer have the right to know the costs of using a credit card? <n> * 3. * a consumer has the right to know the following : * does a consumer have the right to know the costs of using a credit card? <n> * 4. * a consumer has the right to know the following : * does a consumer have the right to know the costs of using a credit card?
# this paper presents a solution to the question of whether or not the sequential rate of growth of a local economy is proportional to the square root of the number of inhabitants.<n> the solution is based on the observation that the growth rate of a local economy is proportional to the square root of the number of inhabitants, rather than the square root of the total number of inhabitants.<n> the solution is based on the observation that the sequential rate of growth of a local economy is proportional to the square root of the number of inhabitants, rather than the total number of inhabitants.<n> the solution is based on the observation that the sequential rate of growth of a local economy is proportional to the square root of the number of inhabitants, rather than the total number of inhabitants.
# this is the version of an article published in the journal of the royal swedish academy of sciences, vol.<n> 44, pp. <n> 1 - 9, 2011, available online at doi : http://dx.doi.org/10.1103/rsa.2011.04.023[http://dx.doi.org/10.1103/rsa.2011.023[http://dx.doi.org/10.1103/rsa.2011.023[http://dx.doi.org/10.1103/rsa.2011.023[http://dx.doi.org/10.1103/rsa.2012.023[http://dx.doi.org/10.1103/rsa.2012.023[http://dx.doi.org/10.1103/rsa.2012.023[http://dx.doi.org/10.1103/rsa.2012.023[http://dx.doi.org/10.1103/rsa.2012.023[http://dx.doi.org/10.1103/rsa.2012.023[http://dx.doi.org/10.1103/rsa.2012.023[http://dx.doi.org/10.1103/rsa.2012.023[http://dx.
# we show that a country s decision to remove an alien may be affected by the fact that the alien has been previously found not to be a citizen of the country.<n> in particular, we show that a country s decision to remove an alien may be affected by the fact that the alien has been previously found not to be a citizen of the country.<n> we also show that a country s decision to remove an alien may be affected by the fact that the alien has been previously found not to be a citizen of the country. <n> we show that a country s decision to remove an alien may be affected by the fact that the alien has been previously found not to be a citizen of the country.<n> in particular, we show that a country s decision to remove an alien may be affected by the fact that the alien has been previously not a citizen of the country. <n> we show that a country s decision to remove an alien may be affected by the fact that the alien has been previously not a citizen of the country. <n> we show that a country s decision to remove an alien may be affected by the fact that the alien has been previously not a citizen of the country.
# we report the results of an evaluation of programs for the prevention of sexually transmitted diseases ( ssdss ).<n> the evaluation was made for programs up to date as of the year 2000.<n> the evaluation was made for programs up to date as of the year 2000.<n> the evaluation was made for programs up to date as of the year 2000.<n> the evaluation was made for programs up to date as of the year 2000. <n> we report the results of an evaluation of programs for the prevention of ssdss.<n> the evaluation was made for programs up to date as of the year 2000.<n> the evaluation was made for programs up to date as of the year 2000. <n> we report the results of an evaluation of programs for the prevention of ssdss.<n> the evaluation was made for programs up to date as of the year 2000.<n> the evaluation was made for programs up to date as of the year 2000.<n> the evaluation was made for programs up to date as of the year 2000. <n> we report the results of an evaluation of programs for the prevention of ssdss.<n> the evaluation was made for
# we establish a national standard for bicycle helmet use, based on the _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# in this brief note, we address the issue of how to determine whether an individual who has been fired for violating a truthfulness condition may also be fired for violating a truthfulness condition.<n> we also address the issue of how to determine whether an individual who has been fired for violating a truthfulness condition may also be fired for violating a truthfulness condition.
# this paper is concerned with the question of whether or not a consumer, using a bank, is able to ascertain whether the sum of the bank s funds is less than the sum of the consumer s funds. <n> _ keywords _ : credit card debt, debit card debt, wire transfer, consumer credit, identity theft, electronic transaction processing. <n> + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + +
# in the united states of america there is an unambiguous conflict of interest between the position of the speaker of the house of representatives and the position of the director of taxation.<n> the position of the speaker of the house of representatives is determined by the rules of the united states of america, whereas the position of the director of taxation is determined by the rules of the united states of america, of the united states of america, of the united states of america, and of the united states of america, respectively.<n> the position of the speaker of the house of representatives is determined by the rules of the united states of america, whereas the position of the director of taxation is determined by the rules of the united states of america, of the united states of america, and of the usa, respectively.<n> the position of the speaker of the house of representatives is determined by the rules of the united states of america, whereas the position of the director of taxation is determined by the rules of the united states of america, of the united states of america, and of the usa, respectively.<n> the position of the speaker of the united states of america is determined by the rules of the united states of america
# in this paper, we address the question of whether or not to define the  quantity'of a substance.<n> we show that the definition of the  quantity'of a substance is different from the definition of the  substance'of that substance.<n> we show that the definition of the  quantity'of a substance is different from the definition of the  substance'of that substance.<n> we also show that the definition of the  quantity'of a substance is different from the definition of the  substance'of that substance. <n> [ [ section ] ] in this paper, we address the question of whether or not to define the  quantity'of a substance.<n> we show that the definition of the  quantity'of a substance is different from the definition of the  substance'of that substance.<n> we show that the definition of the  quantity'of a substance is different from the definition of the  substance'of that substance.<n> we show that the definition of the  quantity'of a substance is different from the definition of the  substance'of that substance. <n> [ [ section ] ]
# we address the following question : is it true that the act of inserting ( a ) by an act of the united states of america into an act of the united states of a separate state of a state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state of another state.
# we show that : 1. ) we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show that ( b ) : we show that ( a ) : we show
# ...
# we show that the fundamental difference between the fundamental right to a fair trial and the fundamental right to a speedy trial does not necessarily translate into a conflict of the present law.<n> we show that the fundamental right to a fair trial and the fundamental right to a speedy trial do not necessarily translate into a conflict of the present law. <n> we show that the fundamental right to a fair trial and the fundamental right to a speedy trial do not necessarily translate into a conflict of the present law. <n> we show that the fundamental right to a fair trial and the fundamental right to a speedy trial do not necessarily translate into a conflict of the present law. <n> we show that the fundamental right to a fair trial and the fundamental right to a speedy trial do not necessarily translate into a conflict of the present law. <n> we show that the fundamental right to a fair trial and the fundamental right to a speedy trial do not necessarily translate into a conflict of the present law. <n> we show that the fundamental right to a fair trial and the fundamental right to a speedy trial do not necessarily translate into a conflict of the present law.
# this case study deals with the storage of natural gas in the state of michigan.<n> the storage of natural gas in the state of michigan has two problems.<n> the first is the storage of natural gas in the state of michigan.<n> the second is the storage of natural gas in the state of michigan.<n> this case study deals with the storage of natural gas in the state of michigan.<n> the first problem is the storage of natural gas in the state of michigan.<n> the state of michigan has two problems.<n> the first is the storage of natural gas in the state of michigan.<n> the state of michigan has two problems.<n> the first is the storage of natural gas in the state of michigan.<n> the state of michigan has two problems.<n> the first is the storage of natural gas in the state of michigan.<n> the state of michigan has two problems.<n> the first is the storage of natural gas in the state of michigan.<n> the state of michigan has two problems.<n> the first is the storage of natural gas in the state of michigan.<n> the state of michigan has two problems
# the purpose of this grant is to provide for the following purposes. 1. <n>. : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# we present the results of an analysis of the cost of nuclear magnetic resonance ( nmr ) nuclear magnetic resonance ( nmr ) imaging.<n> we find that the cost per resident for nmr nuclear magnetic resonance ( nmr ) imaging ranges from approximately $ 100 to about $ 200 depending on the imaging modalities.<n> we also find that the cost per resident scales linearly with the square root of the square root of the number of nmr electrons.<n> the analysis of the nmr imaging data indicates that the nuclear magnetic resonance ( nmr ) intensity scales linearly with the square root of the number of nmr electrons.<n> the analysis of the nmr imaging data indicates that the nuclear magnetic resonance ( nmr ) intensity scales linearly with the number of nmr electrons.<n> the analysis of the nmr imaging data indicates that the nuclear magnetic resonance ( nmr ) intensity scales linearly with the number of nmr electrons.<n> the analysis of the nmr imaging data indicates that the nuclear magnetic resonance ( nmr ) intensity scales linearly with the number of nmr electrons.<n> the analysis of the nmr imaging data indicates that the nuclear magnetic resonance ( nmr ) intensity scales linearly
# we show that there is a conflict of interest between the requirements of a contract and the performance of an acquisition.<n> specifically, we show that there is a conflict of interest between the requirements of a contract and the performance of an acquisition, when the performance of an acquisition is determined by comparing the performance of an acquisition with that of a contract.<n> we also show that there is a conflict of interest when the performance of an acquisition is determined by comparing the performance of an acquisition with that of a contract, when the performance of an acquisition is determined by comparing the performance of an acquisition with that of a contract, when the performance of an acquisition is determined by comparing the performance of an acquisition with that of a contract, when the performance of an acquisition is determined by comparing the performance of an acquisition with that of a contract, when the performance of an acquisition is determined by comparing the performance of an acquisition with that of a contract, when the performance of an acquisition is determined by comparing the performance of an acquisition with that of a contract, when the performance of an acquisition is determined by comparing the performance of an acquisition with that of a contract, when the performance of an acquisition is determined by comparing the performance of an acquisition with that of
# in this article, we address the issue of how to determine whether a fleet of vehicles can be used as a means of transportation.<n> specifically, we address the following question : under what conditions can a fleet of vehicles be used as a means of transportation? <n> first, we address the question of whether or not a fleet of vehicles can be used as a means of transportation.<n> second, we address the question of whether or not a fleet of vehicles can be used as a means of transportation.
# an air carrier is an aircraft that is capable of transporting a passenger in air, in air, or in air.<n> an air carrier is an aircraft that is capable of transporting a passenger in air, in air, or in air.<n> an air carrier is capable of transporting a passenger in air, in air, or in air.<n> an air carrier is an aircraft that is capable of transporting a passenger in air, in air, or in air.<n> an air carrier is an aircraft that is capable of transporting a passenger in air, in air, or in air.<n> an air carrier is an aircraft that is capable of transporting a passenger in air, in air, or in air.<n> an air carrier is an aircraft that is capable of transporting a passenger in air, in air, or in air.<n> an air carrier is an aircraft that is capable of transporting a passenger in air, in air, or in air.<n> an air carrier is an aircraft that is capable of transporting a passenger in air, in air, or in air.<n> an air carrier is an aircraft that is capable of transporting a passenger in air
# we address the question of whether there is a lower bound on the value of a property that can be determined from a biometric system.<n> we show that such a lower bound can be arbitrarily small.<n> specifically, we show that the lower bound on the value of a property obtained from a biometric system is arbitrarily small if the biometric system consists of a set of independent sensors. <n> [ theore]*theorem * [ theore]proposition [ theore]lemma [ theore]corollary [ theore]definition [ theore]example [ theore]exercise [ theore]remark
# in this paper, we address the issue of fees in higher education.<n> we start from the definition of fees in higher education.<n> we then address the issue of fees in higher education. <n> [ theoree]*theorem * [ theoree]_lemma _ [ theoree]proposition [ theoree]corollary [ theoree]definition [ theoree]_problem _ [ theoree]_example _ [ theoree]_exercise _ [ theoree]_remark _ [ theoree]_problem _ [ theoree]_example _
# we address the question of whether there is a relationship between underreporting of production on public lands and underreporting of production on private lands.<n> we show that the answer is affirmative for the following two reasons.<n> first, we show that there is a relationship between underreporting of production on public lands and underreporting of production on private lands.<n> second, we show that the answer to the question of whether there is a relationship between underreporting of production on public lands and underreporting of production on private lands is affirmative for the following two reasons.<n> first, we show that there is a relationship between underreporting of production on public lands and underreporting of production on private lands.<n> second, we show that the answer to the question of whether there is a relationship between underreporting of production on public lands and underreporting of production on private lands is affirmative for the following two reasons.<n> first, we show that there is a relationship between underreporting of production on public lands and underreporting of production on private lands.<n> third, we show that the answer to the question of whether there is a relationship between underreporting of production on public lands and underreporting of production on private lands is affirmative for the following
# in this report, the following questions are addressed. 1. <n> : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :
# we address the question of whether or not an individual who acts as agent for an entity in connection with an ongoing water delivery dispute may also act as an agent for that entity in connection with an ongoing water delivery dispute.<n> we show that an individual who acts as agent for an entity in connection with an ongoing water delivery dispute may also act as an agent for that entity in connection with an ongoing water delivery dispute. <n> _ keywords : _ water allocation, water rights, agent, water rights, dispute, water delivery. <n> we address the question of whether or not an individual who acts as agent for an entity in connection with an ongoing water delivery dispute may also act as an agent for that entity in connection with an ongoing water delivery dispute. <n> we show that an individual who acts as agent for an entity in connection with an ongoing water delivery dispute may also act as an agent for that entity in connection with an ongoing water delivery dispute. <n> we address the question of whether or not an individual who acts as agent for an entity in connection with an ongoing water delivery dispute may also act as an agent for that entity in connection with an ongoing water delivery dispute. <n> we show that an individual
# we consider the question of whether there is a relationship between the cost of an individual s health care and the quality of that health care.<n> specifically, we address the question of whether there is a relationship between the cost of an individual s health care and the quality of that health care.<n> we show that there is a relationship between the price of an individual s health care and the quality of that health care.<n> we show that there is a relationship between the price of an individual s health care and the quality of that health care.<n> we prove that there is a relationship between the price of an individual s health care and the quality of that health care.<n> we prove that there is a relationship between the price of an individual s health care and the quality of that health care.<n> we prove that there is a relationship between the price of an individual s health care and the quality of that health care.<n> we prove that there is a relationship between the price of an individual s health care and the quality of that health care.<n> we prove that there is a relationship between the price of an individual s health care and the quality of that health care.<n> we prove that
# we address the question of whether there is a conflict of interest between the definition of appropriateness for long - term care ( ldcc ) and that of appropriateness for short - term care ( ssc ).<n> we show that, under certain circumstances, ldcc and ssc can be defined equivalently.<n> we also show that, under certain circumstances, ldcc and ssc can be defined similarly.<n> finally, we show that, under certain circumstances, ldcc and ssc can be defined similarly, but not equivalently. <n> long - term care ( lhc ) is the care of an individual for a period of time longer than the age of the individual.<n> the definition of appropriateness for long - term care ( ldcc ) is the following : ldcc is defined as follows : _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# in this brief report, we address some of the issues raised in our recent letter @xcite.<n> specifically, we address the following issues : 1. <n> let us begin with our recent letter @xcite.<n> in this letter, we address some of the issues raised in our recent letter @xcite.<n> specifically, we address the following issues : 1. <n> let us begin with our recent letter @xcite.<n> in this letter, we address some of the issues raised in our recent letter.<n> specifically, we address the following issues : 2. <n> let us begin with our recent letter @xcite.<n> in this letter, we address some of the issues raised in our recent letter.<n> specifically, we address the following issues : 1. <n> let us begin with our recent letter @xcite.<n> in this letter, we address some of the issues raised in our recent letter.<n> specifically, we address the following issues : 2. <n> let us begin with our recent letter.<n> in this letter, we address some of the issues raised in our recent letter
# in this chapter, we provide definitions and examples for the use of the term  active duty'in the definition of an active duty component.<n> we also provide definitions and examples for the use of the term  reserve component'in the definition of a reserve component. <n> [ section ] [ theorem]proposition [ theorem]lemma [ theorem]corollary [ theorem]definition [ theorem]example [ theorem]exercise [ theorem]remark
# this paper presents an analysis of the quality of personal assistance for long - term care ( lac ) programs in the united states.<n> the analysis is based on the definition of lac plan ( licp ) : a plan that provides for the benefits of an individual s long - term care ( ltc ) benefits.<n> the licp is defined as a plan that provides for the benefits of an individual s long - term care ( ltc ) benefits.<n> the analysis is based on the definition of licp as a plan that provides for the benefits of an individual s long - term care ( ltc ) benefits.<n> the licp is defined as a plan that provides for the benefits of an individual s long - term care ( ltc ) benefits.<n> the analysis is based on the definition of licp as a plan that provides for the benefits of an individual s long - term care ( ltc ) benefits.<n> the licp is defined as a plan that provides for the benefits of an individual s long - term care ( ltc ) benefits.<n> the analysis is based on the definition of licp as
# in this brief report, we report the results of our investigation into the nature and origin of the following phenomena : ( i ) the occurrence of a large number of transients in a single site ; ( ii ) the presence of transients in multiple sites ; ( iii ) the presence of transients in multiple sites ; ( iv ) the transient nature of the phenomena ; ( v ) the transient nature of the phenomena ; ( vi ) the transient nature of the phenomena ; ( v ) the transient nature of the phenomena ; ( vi ) the transient nature of the phenomena ; ( v ) the transient nature of the phenomena ; ( vi ) the transient nature of the phenomena ; ( vii ) the transient nature of the phenomena ; ( vi ) the transient nature of the phenomena ; ( v ) the transient nature of the phenomena ; ( vi ) the transient nature of the phenomena ; (vii ) the transient nature of the phenomena ; ( vi ) the transient nature of the phenomena ; ( v ) the transient nature of the phenomena ; ( vi ) the transient nature of the phenomena ; (vii

# %% [markdown]
# Finally, we can evaluate the predictions using the *rouge* metric.

# %%
rouge.compute(predictions=result["predicted_abstract"], references=result["summary"])
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.19358401223508673, recall=0.1637358247547922, fmeasure=0.14659759828823976), mid=Score(precision=0.2215944078386553, recall=0.18116945112520072, fmeasure=0.1606089260734368), high=Score(precision=0.25085208810960036, recall=0.19983779439288984, fmeasure=0.1741686051795053)),
#  'rouge2': AggregateScore(low=Score(precision=0.01993041704405919, recall=0.015102793823906743, fmeasure=0.014237118326248733), mid=Score(precision=0.027535967007829537, recall=0.018797558800413845, fmeasure=0.017330975339198695), high=Score(precision=0.037881973105541346, recall=0.022666397173800142, fmeasure=0.020913443751381874)),
#  'rougeL': AggregateScore(low=Score(precision=0.1524727168604346, recall=0.12910489560908717, fmeasure=0.11415284055111366), mid=Score(precision=0.17038074858919028, recall=0.14420899032016238, fmeasure=0.12454701494818621), high=Score(precision=0.19086367927775097, recall=0.1590382977557767, fmeasure=0.1336304316790825)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.16893009702195522, recall=0.14365085657870852, fmeasure=0.12706230905979907), mid=Score(precision=0.19343571442613516, recall=0.15823398021005902, fmeasure=0.13918097243899352), high=Score(precision=0.2204985095226375, recall=0.17484953467831701, fmeasure=0.15074537416152517))}

# %%
# !pip install git+https://github.com/google-research/bleurt.git
bleurt= load_metric('bleurt')

# %% [markdown]
# For our 600 samples, we get a *Rouge-2* score of **19.6** 🔥🔥🔥.
#
# **Note**: As stated in the [official paper](https://arxiv.org/pdf/2007.14062.pdf) *BigBirdPegasus* achieves a new state-of-the-art of **20.65** Rouge-2 score on PubMed. Evaluation in this notebook might be slightly worse since a different `length_penalty` is used for generation and data pre-processing is kept as simple as possibe (no "*newline*" removal and space removal before special tokens).

# %% [markdown]
# In case you want to evaluate [`google/bigbird-pegasus-large-arxiv`](https://huggingface.co/google/bigbird-pegasus-large-pubmed) on `arxiv` dataset from [`scientific_papers`](https://huggingface.co/datasets/scientific_papers), you can just change the `DATASET_NAME` to `arxiv` in the cell above.

# %%
billsum_rouge_result = rouge.compute(predictions=result["predicted_abstract"], references=result["summary"])
billsum_bleurt_score = bleurt.compute(predictions=result["predicted_abstract"], references=result["summary"])

# %%
import pandas as pd

# %%
dataframe = pd.DataFrame(billsum_rouge_result)
dataframe.to_csv('/content/billsum_rouge_result_beam.csv', index = False)
dataframe = pd.DataFrame(billsum_bleurt_score)
dataframe.to_csv('/content/billsum_bleurt_score_beam.csv', index = False)
